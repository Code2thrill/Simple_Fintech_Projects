# %%
import pandas

# %%
df = pandas.read_csv('nasdaq.csv')

# %%
print(df)
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $156.26
# 1        AA                    Alcoa Corporation Common Stock     $48.80
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.79
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.57
# 4      AACI            Armada Acquisition Corp. I Common Stock     $9.76
# ...     ...                                                ...       ...
# 8242    ZWS      Zurn Water Solutions Corporation Common Stock    $37.47
# 8243     ZY                         Zymergen Inc. Common Stock     $8.15
# 8244   ZYME                       Zymeworks Inc. Common Shares    $16.07
# 8245   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $3.32
# 8246   ZYXI                            Zynex Inc. Common Stock    $11.23
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# ...

# %%
 df.head()
# Out:
#   Symbol                                               Name Last Sale  \
# 0      A             Agilent Technologies Inc. Common Stock   $156.26
# 1     AA                    Alcoa Corporation Common Stock     $48.80
# 2    AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.79
# 3   AACG   ATA Creativity Global American Depositary Shares     $1.57
# 4   AACI            Armada Acquisition Corp. I Common Stock     $9.76
#
#    Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0        1.65   1.067%  4.730344e+10  United States    1999.0  1463448
# 1       -1.18  -2.361%  9.130634e+09            NaN    2016.0  5524945
# 2        0.01   0.102%  1.223750e+09            NaN    2021.0    10091
# 3        0.00    0.00%  4.926176e+07          China       NaN    10430
# 4        0.00    0.00%  2.021247e+08  United States    2021.0    29211
#
#              Sector                        Industry
# 0     Capital Goods             Electrical Products
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8247 entries, 0 to 8246
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      8247 non-null   object
#  1   Name        8247 non-null   object
#  2   Last Sale   8247 non-null   object
#  3   Net Change  8247 non-null   float64
#  4   % Change    8241 non-null   object
#  5   Market Cap  7773 non-null   float64
#  6   Country     7500 non-null   object
#  7   IPO Year    4854 non-null   float64
#  8   Volume      8247 non-null   int64
#  9   Sector      6180 non-null   object
#  10  Industry    6196 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 708.9+ KB

# %%
df.describe()
# Out:
#         Net Change    Market Cap     IPO Year        Volume
# count  8247.000000  7.773000e+03  4854.000000  8.247000e+03
# mean      0.813674  8.675454e+09  2014.602390  9.555662e+05
# std      72.695782  6.750177e+10     9.029094  5.085651e+06
# min     -54.000000  0.000000e+00  1972.000000  1.000000e+00
# 25%      -0.130000  6.815802e+07  2013.000000  1.764200e+04
# 50%      -0.010000  4.221928e+08  2019.000000  1.186340e+05
# 75%       0.075600  2.594295e+09  2021.000000  5.525155e+05
# max    6598.000000  3.111186e+12  2021.000000  2.917001e+08

# %%
from jupyter_dash import JupyterDash

import dash

import dash_html_components as html

import dash_core_components as dcc

from datetime import datetime

app = JupyterDash(__name__)

options = []

for element in df.index:

  options.append({"label": df["Name"][element],
                  "value": df["Symbol"][element]
                  })

app.layout = html.Div([
                       html.H1("Stock Ticker Web App"),
                       html.Div([
                                 html.H2("Select a stock:"),
                                 dcc.Dropdown(
                                     id = "dropdown",
                                     options = options,
                                     value = ["GOOG"],
                                     multi = True
                                 )
                       ]),
                       html.Div([
                                 html.H2("Select Date"),
                                 dcc.DatePickerRange(
                                     id = "datepicker",
                                     min_date_allowed = datetime(2017, 
                                                                 1, 
                                                                 1),
                                     max_date_allowed = datetime.today(),
                                     start_date = datetime(2020, 1, 1),
                                     end_date = datetime.today()
                                 )
                       ]),
                       html.Div([
                                 html.Button(
                                     id = "submit-button",
                                     n_clicks = 0,
                                     children = "Submit"
                                 )
                       ]),
                       dcc.Graph(
                           id = "stock-graph"
                       )
])

# %%
app.run_server(port = 3030)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
# ...
